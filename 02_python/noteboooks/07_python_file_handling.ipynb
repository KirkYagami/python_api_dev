# %%
f = open('data.txt', 'r')

content = f.read()
f.close()
print(content)
# Out:
# First line

# %%
with open('data.txt', 'r') as f:
    c = f.read()

print(c)
# Out:
# First line

# %%
with open('data.txt', 'r') as f:
    content = "Second line"
    f.write(content)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[9], line 3
#       1 with open('data.txt', 'r') as f:
#       2     content = "Second line"
# ----> 3     f.write(content)
#
# UnsupportedOperation: not writable

# %%
with open('data.txt', 'a') as f:
    content = "Second line"
    f.write(content)

# %%
with open('data.txt', 'r') as f:
    c = f.read()

print(c)
# Out:
# First lineSecond line

# %%
with open('data.txt', 'a') as f:
    content = "\n\nSecond line"
    f.write(content)

with open('data.txt', 'r') as f:
    c = f.read()

print(c)
# Out:
# First lineSecond line
#
# Second line

# %%
with open('Anne_H.jpg', 'rb') as file:
    content = file.read()
    print(type(content))
    print(len(content), "bytes read")
# Out:
# <class 'bytes'>
# 72007 bytes read

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('Anne_H.jpg')


plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# Out:
# 90

# %%
from IPython.display import Image, display


filenames = ['Anne_H.jpg', 'image2.png' ]
for filename in filenames:
    display(Image(filename=filename))

# %%
## Writing a file(Overwriting)

with open('example.txt','w') as file:
    file.write('Hello World!\n')
    file.write('this is a new line.')

# %%
## Read a file line by line
with open('example.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# Hello World!
# this is a new line.

# %%
## Write a file(without Overwriting)
with open('example.txt','a') as file:
    file.write("Append operation taking place!\n")

# %%
### Writing a list of lines to a file
lines=['First line \n','Second line \n','Third line\n']
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
#Read a text file and count the number of lines, words, and characters.
# Counting lines, words, and characters in a text file
def count_text_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line) for line in lines)
    return line_count, word_count, char_count

file_path = 'example.txt'
lines, words, characters = count_text_file(file_path)
print(f'Lines: {lines}, Words: {words}, Characters: {characters}')
# Out:
# Lines: 4, Words: 12, Characters: 68

# %%
import os, glob

# Get absolute paths
abs_paths = [os.path.abspath(f) for f in glob.glob('*.jpg')]

# Combine with directory paths
pattern = os.path.join('data', '*.csv')
csv_files = glob.glob(pattern)

# %%
abs_paths
# Out:
# ['c:\\dev01\\04_python_api_dev\\02_python\\noteboooks\\Anne_H.jpg']
